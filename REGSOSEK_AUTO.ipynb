# %%
from pywinauto.application import Application
import pywinauto
from pywinauto import *
from time import sleep
from tqdm import tqdm
from pywinauto.timings import wait_until, wait_until_passes

# %%
def insert_item(kode_prov, kode_kab, kode_kec, kode_desa, kode_sls, kode_sub_sls, nama_sls, r107, r108, r109, r110, r111, r112, r113, r114, r115, art, key_idsls_no_kv):
    import mariadb
    connection = mariadb.connect(
    host="10.16.8.100",
    user="root",
    password="",
    database='regsosek_entri'
    )
    cursor = connection.cursor()
    query = '''INSERT INTO data_entri 
    (kode_prov, 
    kode_kab,
    kode_kec, 
    kode_desa, 
    kode_sls, 
    kode_sub_sls, 
    nama_sls, 
    alamat,
    nama_kk,
    no_urut_bangunan,
    no_urut_verifikasi,
    status_keluarga,
    jumlah_art,
    id_wilkerstat,
    no_kk,
    kode_kk,
    art,
    key_idsls_no_kv) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
    values = (kode_prov, kode_kab, kode_kec, kode_desa, kode_sls, kode_sub_sls, nama_sls, r107, r108, int(r109), int(r110), int(r111), r112, r113, r114, int(r115), art, key_idsls_no_kv)
    cursor.execute(query, values)
    connection.commit()

# %%
def get_data(app, app_dlg, list_k, nu_vk_max):
    for index_k in range(0, len(list_k)):
        
        app.window(best_match='Regsosek 2022').wait('visible enabled', 60)  
        sleep(2)       
           
        try:
            list_k[index_k].select()
        except:
            list_k[index_k].click_input()
            list_k[index_k].click_input()
        
        try_get_details = True

        while(try_get_details):
            try:
                entry_btn = app_dlg.child_window(title="[F12] Entry", control_type="Button")
                entry_btn.click()
                
                app.window(best_match='Dialog0').wait('visible', 60)
                entry_dlg = app.window(best_match='Dialog0')

                tab_hal_2 = entry_dlg.child_window(title="Halaman 2", control_type="TabItem")
                close_btn = entry_dlg.child_window(auto_id="btnClose", control_type="Button")
            
                kode_prov = entry_dlg.child_window(auto_id="kode_prov", control_type="Edit").window_text()
                kode_kab = entry_dlg.child_window(auto_id="kode_kab", control_type="Edit").window_text()
                kode_kec = entry_dlg.child_window(auto_id="kode_kec", control_type="Edit").window_text()
                kode_desa = entry_dlg.child_window(auto_id="kode_desa", control_type="Edit").window_text()
                kode_sls = entry_dlg.child_window(auto_id="kode_sls", control_type="Edit").window_text()
                kode_sub_sls = entry_dlg.child_window(auto_id="kode_subsls", control_type="Edit").window_text()
                nama_sls = entry_dlg.child_window(auto_id="sls_nama", control_type="Edit").window_text()
                r107 = entry_dlg.child_window(auto_id="alamat_temp", control_type="Edit").window_text()
                r108 = entry_dlg.child_window(auto_id="r108_temp", control_type="Edit").window_text()
                r109 = entry_dlg.child_window(auto_id="r109", control_type="Edit").window_text()
                r110 = entry_dlg.child_window(auto_id="r110", control_type="Edit").window_text()
                r111 = entry_dlg.child_window(auto_id="r111", control_type="Edit").window_text()
                r112 = entry_dlg.child_window(auto_id="r112", control_type="Edit").window_text()
                r113 = entry_dlg.child_window(auto_id="r113", control_type="Edit").window_text()
                r114 = entry_dlg.child_window(auto_id="r114_temp", control_type="Edit").window_text()
                r115 = entry_dlg.child_window(auto_id="r115", control_type="Edit").window_text()
                keys = kode_prov+kode_kab+kode_kec+kode_desa+kode_sls+kode_sub_sls+'_'+r110
                

                tab_hal_2.select()
                list_art = entry_dlg.children()[1].children(title='Halaman 2')[0].children()[1].children()[0].children(control_type='Pane')[0].children(control_type='Pane')[0].children(control_type='Custom')
                list_data_art = []
                for art in list_art:
                    r401 = art.children()[0].children(control_type="Edit")[0].window_text()
                    r402 = art.children()[0].children(control_type="Edit")[1].window_text()
                    r403 = art.children()[0].children(control_type="Edit")[2].window_text()
                    data_art = {'r401':r401, 'r402':r402, 'r403':r403}
                    list_data_art.append(data_art)
                
                import json
                data_art_json = json.dumps(list_data_art)

                insert_item(kode_prov=kode_prov, kode_kab=kode_kab, kode_kec=kode_kec, kode_desa=kode_desa, kode_sls=kode_sls, kode_sub_sls=kode_sub_sls, nama_sls=nama_sls, r107=r107, r108=r108, r109=r109, r110=r110, r111=r111, r112=r112, r113=r113, r114=r114, r115=r115, art=data_art_json, key_idsls_no_kv=keys)

                close_btn.click()
                entry_dlg.descendants(title='No', control_type='Button')[0].click()
                sleep(2)
                app.window(best_match='Regsosek 2022').wait('visible enabled', 60)

                try_get_details = False  
            
            except:
                if(len(app_dlg.descendants(title='Error'))>0):
                    app_dlg.descendants(title='OK')[0].type_keys('{ENTER}')
                    try:
                        list_k[index_k].select()
                    except:
                        list_k[index_k].click_input()
                        list_k[index_k].click_input()

# %%
def scrap_regsosek():
    app = Application(backend='uia').connect(best_match='Regsosek 2022')
    app_dlg = app.window(best_match='Regsosek 2022')

    entry_k_btn = app_dlg.children()[1].children()[0].children()[0].children()[1]
    entry_k_btn.click()

    filter_wilayah = app_dlg.children()[4].children(class_name='TabControl')[0].children()[0].children()[1].children()[0].children(class_name='ComboBox')

    combo_kab = filter_wilayah[1]
    combo_kab.type_keys("%{DOWN}")
    list_kab = combo_kab.children()
    # loop kab
    for kab in list_kab[3:]:
        kab.select()
        combo_kab.type_keys("%{ENTER}")

        # loop kec
        combo_kec = filter_wilayah[2]
        combo_kec.type_keys("%{DOWN}")
        list_kec = combo_kec.children()
        for kec in list_kec:
            kec.select()
            combo_kec.type_keys("%{ENTER}")
        
            # loop desa 
            combo_desa = filter_wilayah[3]
            combo_desa.type_keys("%{DOWN}")
            list_desa = combo_desa.children()
            for desa in list_desa:
                desa.select()
                combo_desa.type_keys("%{ENTER}")

                # loop sls

                combo_sls = filter_wilayah[4]
                combo_sls.type_keys("%{DOWN}")
                list_sls = combo_sls.children()
                for sls in list_sls:
                    sleep(1)
                    try:
                        sls.select()
                    except:
                        sls.click_input()
                    
                    combo_sls.type_keys("%{ENTER}")
                    sleep(1)
                    if(len(app_dlg.window(auto_id='grid_data').children())>1):
                        list_k = app_dlg.window(auto_id='grid_data').children(control_type = 'DataItem')
                        nu_vk_max = int(list_k[0].children()[3].window_text())

                        list_k_0 = app_dlg.window(auto_id='grid_data').children(control_type = 'DataItem')
                        nu_vk_max = int(list_k[0].children()[3].window_text())

                        n_loop = nu_vk_max // (len(list_k_0)-1)
                        mod_loop = nu_vk_max % (len(list_k_0)-1)

                        print(f'nu vk max : {nu_vk_max}')
                        print(f'visible rows : {len(list_k_0)}')
                        print(f'n loop : {n_loop}')

                        if(mod_loop>0):
                            n_loop = n_loop+1

                        for n in range(0, n_loop):
                            print(f'loop get data ke {n}')
                            list_k = app_dlg.window(auto_id='grid_data').children(control_type = 'DataItem')
                            get_data(app, app_dlg, list_k, nu_vk_max)  

                            for m in range(0, n_loop-1):
                                print(f'loop scroll ke {m}')
                                if(m==n_loop-2):
                                    for l in range(0, len(mod_loop)):
                                        app = Application(backend='uia').connect(best_match='Regsosek 2022')
                                        app_dlg = app.window(best_match='Regsosek 2022')
                                        list_k = app_dlg.window(auto_id='grid_data').children(control_type = 'DataItem')
                                        list_k[len(list_k)-1].click_input()
                                        list_k[len(list_k)-1].click_input()
                                        app_dlg.type_keys('{DOWN}')
                                else:
                                    for l in range(0, len(list_k_0)):
                                        app = Application(backend='uia').connect(best_match='Regsosek 2022')
                                        app_dlg = app.window(best_match='Regsosek 2022')
                                        list_k = app_dlg.window(auto_id='grid_data').children(control_type = 'DataItem')
                                        list_k[len(list_k)-1].click_input()
                                        list_k[len(list_k)-1].click_input()
                                        app_dlg.type_keys('{DOWN}')

# %%
scrap_regsosek()

# %%
app_dlg.print_control_identifiers()
# Out:
# Control Identifiers:
#
# Dialog - 'Regsosek 2022'    (L-8, T-8, R1928, B1048)
# ['Regsosek 2022Dialog', 'Regsosek 2022', 'Dialog', 'Regsosek 20220', 'Regsosek 20221']
# child_window(title="Regsosek 2022", auto_id="formMain", control_type="Window")
#    |
#    | TitleBar - ''    (L16, T-5, R1920, B23)
#    | ['TitleBar']
#    |    |
#    |    | Menu - 'System'    (L0, T0, R22, B22)
#    |    | ['Menu', 'SystemMenu', 'System', 'System0', 'System1']
#    |    | child_window(title="System", auto_id="MenuBar", control_type="MenuBar")
#    |    |    |
#    |    |    | MenuItem - 'System'    (L0, T0, R22, B22)
#    |    |    | ['System2', 'SystemMenuItem', 'MenuItem']
#    |    |    | child_window(title="System", control_type="MenuItem")
#    |    |
#    |    | Button - 'Minimize'    (L1779, T8, R1826, B22)
#    |    | ['Button', 'MinimizeButton', 'Minimize', 'Button0', 'Button1']
#    |    | child_window(title="Minimize", control_type="Button")
#    |    |
#    |    | Button - 'Restore'    (L1826, T8, R1872, B22)
#    |    | ['Button2', 'Restore', 'RestoreButton']
#    |    | child_window(title="Restore", control_type="Button")
#    |    |
#    |    | Button - 'Close'    (L1872, T8, R1928, B22)
#    |    | ['Close', 'Button3', 'CloseButton', 'Close0', 'Close1', 'CloseButton0', 'CloseButton1']
#    |    | child_window(title="Close", control_type="Button")
#    |
#    | Custom - ''    (L0, T23, R1920, B125)
#    | ['HomeCustom', 'Custom', 'Custom0', 'Custom1']
#    |    |
#    |    | TabControl - ''    (L3, T24, R1917, B124)
#    |    | ['HomeTabControl', 'TabControl', 'TabControl0', 'TabControl1']
#    |    |    |
#    |    |    | TabItem - 'Home'    (L5, T24, R80, B46)
#    |    |    | ['Home', 'HomeTabItem', 'TabItem', 'Home0', 'Home1', 'TabItem0', 'TabItem1']
#    |    |    | child_window(title="Home", control_type="TabItem")
#    |    |    |    |
#    |    |    |    | Static - 'Home'    (L26, T27, R59, B43)
#    |    |    |    | ['Static', 'Home2', 'HomeStatic', 'Static0', 'Static1']
#    |    |    |    | child_window(title="Home", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L10, T51, R98, B119)
#    |    |    |    | ['HomeButton', 'Button4', 'HomeButton0', 'HomeButton1']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Entri K'    (L37, T94, R71, B110)
#    |    |    |    |    | ['Static2', 'Entri K', 'Entri KStatic']
#    |    |    |    |    | child_window(title="Entri K", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L106, T51, R194, B119)
#    |    |    |    | ['HomeButton2', 'Button5', 'Entri KButton']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Entri XK'    (L129, T94, R171, B110)
#    |    |    |    |    | ['Static3', 'Entri XK', 'Entri XKStatic']
#    |    |    |    |    | child_window(title="Entri XK", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L202, T51, R300, B119)
#    |    |    |    | ['Entri XKButton', 'Button6']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Finalisasi Data'    (L214, T94, R288, B110)
#    |    |    |    |    | ['Static4', 'Finalisasi DataStatic', 'Finalisasi Data']
#    |    |    |    |    | child_window(title="Finalisasi Data", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button7']
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button8']
#    |    |    |    |
#    |    |    |    | Button - ''    (L210, T51, R288, B119)
#    |    |    |    | ['Button9', 'WilayahButton', 'WilayahButton0', 'WilayahButton1']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Wilayah'    (L228, T94, R270, B110)
#    |    |    |    |    | ['Static5', 'Wilayah', 'WilayahStatic']
#    |    |    |    |    | child_window(title="Wilayah", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button10']
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button11']
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button12']
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button13']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Operator'    (L417, T98, R465, B114)
#    |    |    |    |    | ['Static6', 'Operator', 'OperatorStatic']
#    |    |    |    |    | child_window(title="Operator", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button14']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Petugas'    (L500, T94, R542, B110)
#    |    |    |    |    | ['Static7', 'Petugas', 'PetugasStatic']
#    |    |    |    |    | child_window(title="Petugas", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L576, T51, R654, B119)
#    |    |    |    | ['Button15', 'LogOutButton', 'LogOutButton0', 'LogOutButton1']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Report'    (L597, T94, R633, B110)
#    |    |    |    |    | ['Static8', 'ReportStatic', 'Report']
#    |    |    |    |    | child_window(title="Report", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button16']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Revalidasi'    (L706, T90, R757, B106)
#    |    |    |    |    | ['Static9', 'Revalidasi', 'RevalidasiStatic']
#    |    |    |    |    | child_window(title="Revalidasi", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button17']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Unlock Docs'    (L699, T116, R765, B132)
#    |    |    |    |    | ['Static10', 'Unlock Docs', 'Unlock DocsStatic']
#    |    |    |    |    | child_window(title="Unlock Docs", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L772, T54, R850, B122)
#    |    |    |    | ['Button18', 'LogOutButton2']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Query Tools'    (L780, T97, R842, B113)
#    |    |    |    |    | ['Static11', 'Query Tools', 'Query ToolsStatic']
#    |    |    |    |    | child_window(title="Query Tools", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button19']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Database'    (L869, T99, R919, B115)
#    |    |    |    |    | ['Static12', 'Database', 'DatabaseStatic']
#    |    |    |    |    | child_window(title="Database", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L0, T0, R0, B0)
#    |    |    |    | ['Button20']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Upload'    (L947, T100, R1001, B116)
#    |    |    |    |    | ['Static13', 'UploadStatic', 'Upload']
#    |    |    |    |    | child_window(title="Upload", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L305, T52, R385, B118)
#    |    |    |    | ['Button21', 'WilayahButton2']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'About'    (L328, T97, R362, B113)
#    |    |    |    |    | ['Static14', 'About', 'AboutStatic']
#    |    |    |    |    | child_window(title="About", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L386, T53, R481, B83)
#    |    |    |    | ['Button22', 'LogOutButton3']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'LogOut'    (L424, T58, R463, B78)
#    |    |    |    |    | ['Static15', 'LogOut', 'LogOutStatic']
#    |    |    |    |    | child_window(title="LogOut", control_type="Text")
#    |    |    |    |
#    |    |    |    | Button - ''    (L386, T85, R481, B115)
#    |    |    |    | ['Button23', 'AboutButton', 'LogOutButton4']
#    |    |    |    |    |
#    |    |    |    |    | Static - 'Close'    (L429, T90, R458, B110)
#    |    |    |    |    | ['Static16', 'Close2', 'CloseStatic']
#    |    |    |    |    | child_window(title="Close", control_type="Text")
#    |
#    | Image - ''    (L166, T125, R1754, B1018)
#    | ['CloseImage', 'Image', 'Entri XKImage']
#    |
#    | StatusBar - ''    (L0, T1018, R1920, B1040)
#    | ['StatusBar', 'Server : 10.16.10.185\\SQLREGSOSEKStatusBar']
#    |    |
#    |    | Static - 'Server : 10.16.10.185\SQLREGSOSEK'    (L0, T1018, R196, B1040)
#    |    | ['Static17', 'Server : 10.16.10.185\\SQLREGSOSEKStatic', 'Server : 10.16.10.185\\SQLREGSOSEK', 'Server : 10.16.10.185\\SQLREGSOSEKStatic0', 'Server : 10.16.10.185\\SQLREGSOSEKStatic1', 'Server : 10.16.10.185\\SQLREGSOSEK0', 'Server : 10.16.10.185\\SQLREGSOSEK1']
#    |    | child_window(title="Server : 10.16.10.185\SQLREGSOSEK", control_type="Text")
#    |    |    |
#    |    |    | Static - 'Server : 10.16.10.185\SQLREGSOSEK'    (L3, T1021, R193, B1037)
#    |    |    | ['Static18', 'Server : 10.16.10.185\\SQLREGSOSEKStatic2', 'Server : 10.16.10.185\\SQLREGSOSEK2']
#    |    |    | child_window(title="Server : 10.16.10.185\SQLREGSOSEK", control_type="Text")
#    |    |
#    |    | Separator - ''    (L198, T1020, R199, B1038)
#    |    | ['Server : 10.16.10.185\\SQLREGSOSEKSeparator', 'Separator', 'Separator0', 'Separator1']
#    |    |
#    |    | Static - 'App Version : 3.0'    (L201, T1018, R296, B1040)
#    |    | ['Static19', 'App Version : 3.0Static', 'App Version : 3.0', 'App Version : 3.0Static0', 'App Version : 3.0Static1', 'App Version : 3.00', 'App Version : 3.01']
#    |    | child_window(title="App Version : 3.0", control_type="Text")
#    |    |    |
#    |    |    | Static - 'App Version : 3.0'    (L204, T1021, R293, B1037)
#    |    |    | ['Static20', 'App Version : 3.0Static2', 'App Version : 3.02']
#    |    |    | child_window(title="App Version : 3.0", control_type="Text")
#    |    |
#    |    | Separator - ''    (L298, T1020, R299, B1038)
#    |    | ['Separator2', 'App Version : 3.0Separator']
#    |    |
#    |    | Static - 'DbVersion : 3.0'    (L301, T1018, R386, B1040)
#    |    | ['Static21', 'DbVersion : 3.0', 'DbVersion : 3.0Static', 'DbVersion : 3.00', 'DbVersion : 3.01', 'DbVersion : 3.0Static0', 'DbVersion : 3.0Static1']
#    |    | child_window(title="DbVersion : 3.0", control_type="Text")
#    |    |    |
#    |    |    | Static - 'DbVersion : 3.0'    (L304, T1021, R383, B1037)
#    |    |    | ['Static22', 'DbVersion : 3.02', 'DbVersion : 3.0Static2']
#    |    |    | child_window(title="DbVersion : 3.0", control_type="Text")
#    |    |
#    |    | Static - 'VersiRule : 3'    (L386, T1018, R456, B1040)
#    |    | ['Static23', 'VersiRule : 3', 'VersiRule : 3Static', 'VersiRule : 30', 'VersiRule : 31', 'VersiRule : 3Static0', 'VersiRule : 3Static1']
#    |    | child_window(title="VersiRule : 3", control_type="Text")
#    |    |    |
#    |    |    | Static - 'VersiRule : 3'    (L389, T1021, R453, B1037)
#    |    |    | ['Static24', 'VersiRule : 32', 'VersiRule : 3Static2']
#    |    |    | child_window(title="VersiRule : 3", control_type="Text")
#    |    |
#    |    | Separator - ''    (L458, T1020, R459, B1038)
#    |    | ['VersiRule : 3Separator', 'Separator3']
#    |    |
#    |    | Static - 'Operator : BPS SUMSEL'    (L461, T1018, R1920, B1040)
#    |    | ['Static25', 'Operator : BPS SUMSEL', 'Operator : BPS SUMSELStatic', 'Operator : BPS SUMSEL0', 'Operator : BPS SUMSEL1', 'Operator : BPS SUMSELStatic0', 'Operator : BPS SUMSELStatic1']
#    |    | child_window(title="Operator : BPS SUMSEL", control_type="Text")
#    |    |    |
#    |    |    | Static - 'Operator : BPS SUMSEL'    (L464, T1021, R588, B1037)
#    |    |    | ['Static26', 'Operator : BPS SUMSEL2', 'Operator : BPS SUMSELStatic2']
#    |    |    | child_window(title="Operator : BPS SUMSEL", control_type="Text")
#    |
#    | Custom - ''    (L10, T135, R1910, B1008)
#    | ['Custom2', 'Entri KCustom']
#    | child_window(auto_id="form", control_type="Custom")
#    |    |
#    |    | Static - 'Data Entry K'    (L43, T168, R1877, B195)
#    |    | ['Static27', 'Data Entry K', 'Data Entry KStatic']
#    |    | child_window(title="Data Entry K", control_type="Text")
#    |    |
#    |    | TabControl - ''    (L26, T212, R1894, B955)
#    |    | ['Data Entry KTabControl', 'TabControl2']
#    |    |    |
#    |    |    | TabItem - 'Regsosek 2022'    (L28, T212, R228, B234)
#    |    |    | ['Regsosek 2022TabItem', 'Regsosek 20222', 'TabItem2']
#    |    |    | child_window(title="Regsosek 2022", control_type="TabItem")
#    |    |    |    |
#    |    |    |    | Static - 'Regsosek 2022'    (L89, T215, R167, B231)
#    |    |    |    | ['Static28', 'Regsosek 2022Static', 'Regsosek 20223']
#    |    |    |    | child_window(title="Regsosek 2022", control_type="Text")
#    |    |    |    |
#    |    |    |    | Custom - ''    (L29, T237, R1891, B952)
#    |    |    |    | ['Custom3', 'Provinsi : Custom', 'Regsosek 2022Custom', 'Provinsi : Custom0', 'Provinsi : Custom1']
#    |    |    |    | child_window(auto_id="form_ppls", control_type="Custom")
#    |    |    |    |    |
#    |    |    |    |    | Custom - ''    (L39, T242, R1580, B372)
#    |    |    |    |    | ['Custom4', 'Provinsi : Custom2']
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - 'Provinsi : '    (L39, T247, R139, B263)
#    |    |    |    |    |    | ['Static29', 'Provinsi : Static', 'Provinsi : ']
#    |    |    |    |    |    | child_window(title="Provinsi : ", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | ComboBox - ''    (L139, T244, R1580, B266)
#    |    |    |    |    |    | ['ComboBox', 'Provinsi : ComboBox', 'ComboBox0', 'ComboBox1']
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - 'Kabupaten : '    (L39, T273, R139, B289)
#    |    |    |    |    |    | ['Static30', 'Kabupaten : ', 'Kabupaten : Static']
#    |    |    |    |    |    | child_window(title="Kabupaten : ", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | ComboBox - ''    (L139, T270, R1580, B292)
#    |    |    |    |    |    | ['ComboBox[05] MUSI RAWAS', 'ComboBox[04] LAHAT', 'ComboBox[07] BANYU ASIN', 'ComboBox[08] OGAN KOMERING ULU SELATAN', 'ComboBox[10] OGAN ILIR', 'ComboBox[12] PENUKAL ABAB LEMATANG ILIR', 'ComboBox[71] PALEMBANG', 'ComboBox[06] MUSI BANYUASIN', 'ComboBox[72] PRABUMULIH', 'ComboBox2', 'ComboBox[11] EMPAT LAWANG', 'Kabupaten : ComboBox', 'ComboBox[74] LUBUKLINGGAU', 'ComboBox[03] MUARA ENIM', 'ComboBox[02] OGAN KOMERING ILIR', 'ComboBox[13] MUSI RAWAS UTARA', 'ComboBox[09] OGAN KOMERING ULU TIMUR', 'ComboBox[73] PAGAR ALAM']
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D', 'ListItem0', 'ListItem1', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem0', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem1', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D0', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D1']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[01] OGAN KOMERING ULU'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static31', '[01] OGAN KOMERING ULU', '[01] OGAN KOMERING ULUStatic']
#    |    |    |    |    |    |    |    | child_window(title="[01] OGAN KOMERING ULU", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem2', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem2', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D2']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[02] OGAN KOMERING ILIR'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static32', '[02] OGAN KOMERING ILIRStatic', '[02] OGAN KOMERING ILIR']
#    |    |    |    |    |    |    |    | child_window(title="[02] OGAN KOMERING ILIR", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem3', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem3', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D3']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[03] MUARA ENIM'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static33', '[03] MUARA ENIMStatic', '[03] MUARA ENIM']
#    |    |    |    |    |    |    |    | child_window(title="[03] MUARA ENIM", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem4', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem4', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D4']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[04] LAHAT'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static34', '[04] LAHAT', '[04] LAHATStatic']
#    |    |    |    |    |    |    |    | child_window(title="[04] LAHAT", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem5', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem5', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D5']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[05] MUSI RAWAS'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static35', '[05] MUSI RAWAS', '[05] MUSI RAWASStatic']
#    |    |    |    |    |    |    |    | child_window(title="[05] MUSI RAWAS", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem6', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem6', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D6']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[06] MUSI BANYUASIN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static36', '[06] MUSI BANYUASINStatic', '[06] MUSI BANYUASIN']
#    |    |    |    |    |    |    |    | child_window(title="[06] MUSI BANYUASIN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem7', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem7', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D7']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[07] BANYU ASIN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static37', '[07] BANYU ASIN', '[07] BANYU ASINStatic']
#    |    |    |    |    |    |    |    | child_window(title="[07] BANYU ASIN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem8', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem8', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D8']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[08] OGAN KOMERING ULU SELATAN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static38', '[08] OGAN KOMERING ULU SELATANStatic', '[08] OGAN KOMERING ULU SELATAN']
#    |    |    |    |    |    |    |    | child_window(title="[08] OGAN KOMERING ULU SELATAN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem9', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem9', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D9']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[09] OGAN KOMERING ULU TIMUR'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static39', '[09] OGAN KOMERING ULU TIMUR', '[09] OGAN KOMERING ULU TIMURStatic']
#    |    |    |    |    |    |    |    | child_window(title="[09] OGAN KOMERING ULU TIMUR", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem10', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem10', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D10']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[10] OGAN ILIR'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static40', '[10] OGAN ILIRStatic', '[10] OGAN ILIR']
#    |    |    |    |    |    |    |    | child_window(title="[10] OGAN ILIR", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem11', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem11', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D11']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[11] EMPAT LAWANG'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static41', '[11] EMPAT LAWANGStatic', '[11] EMPAT LAWANG']
#    |    |    |    |    |    |    |    | child_window(title="[11] EMPAT LAWANG", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem12', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem12', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D12']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[12] PENUKAL ABAB LEMATANG ILIR'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static42', '[12] PENUKAL ABAB LEMATANG ILIR', '[12] PENUKAL ABAB LEMATANG ILIRStatic']
#    |    |    |    |    |    |    |    | child_window(title="[12] PENUKAL ABAB LEMATANG ILIR", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem13', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem13', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D13']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[13] MUSI RAWAS UTARA'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static43', '[13] MUSI RAWAS UTARAStatic', '[13] MUSI RAWAS UTARA']
#    |    |    |    |    |    |    |    | child_window(title="[13] MUSI RAWAS UTARA", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem14', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem14', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D14']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[71] PALEMBANG'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static44', '[71] PALEMBANG', '[71] PALEMBANGStatic']
#    |    |    |    |    |    |    |    | child_window(title="[71] PALEMBANG", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem15', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem15', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D15']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[72] PRABUMULIH'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static45', '[72] PRABUMULIHStatic', '[72] PRABUMULIH']
#    |    |    |    |    |    |    |    | child_window(title="[72] PRABUMULIH", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem16', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem16', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D16']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[73] PAGAR ALAM'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static46', '[73] PAGAR ALAMStatic', '[73] PAGAR ALAM']
#    |    |    |    |    |    |    |    | child_window(title="[73] PAGAR ALAM", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem17', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70DListItem17', 'System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D17']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kab_2A2F5DCAABB631D3DED4249EE9AA9BC587C4E8A23C6060382BD11116F0EFF70D", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[74] LUBUKLINGGAU'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static47', '[74] LUBUKLINGGAU', '[74] LUBUKLINGGAUStatic']
#    |    |    |    |    |    |    |    | child_window(title="[74] LUBUKLINGGAU", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - 'Kecamatan : '    (L39, T299, R139, B315)
#    |    |    |    |    |    | ['Static48', 'Kecamatan : ', 'Kecamatan : Static']
#    |    |    |    |    |    | child_window(title="Kecamatan : ", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | ComboBox - ''    (L139, T296, R1580, B318)
#    |    |    |    |    |    | ['ComboBox3', 'ComboBox[092] SINAR PENINJAUAN', 'ComboBox[140] BATU RAJA BARAT', 'ComboBox[130] BATU RAJA TIMUR', 'ComboBox[091] LUBUK BATANG', 'ComboBox[082] ULU OGAN', 'ComboBox[090] PENINJAUAN', 'ComboBox[080] PENGANDONAN', 'ComboBox[083] MUARA JAYA', 'ComboBox[131] LUBUK RAJA', 'Kecamatan : ComboBox', 'ComboBox[070] SOSOH BUAY RAYAP', 'ComboBox[081] SEMIDANG AJI', 'ComboBox[093] KEDATON PENINJAUAN RAYA']
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem18', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD0', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD1', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem0', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem1']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[052] LENGKITI'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static49', '[052] LENGKITI', '[052] LENGKITIStatic']
#    |    |    |    |    |    |    |    | child_window(title="[052] LENGKITI", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem19', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD2', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem2']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[070] SOSOH BUAY RAYAP'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static50', '[070] SOSOH BUAY RAYAP', '[070] SOSOH BUAY RAYAPStatic']
#    |    |    |    |    |    |    |    | child_window(title="[070] SOSOH BUAY RAYAP", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem20', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD3', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem3']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[080] PENGANDONAN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static51', '[080] PENGANDONAN', '[080] PENGANDONANStatic']
#    |    |    |    |    |    |    |    | child_window(title="[080] PENGANDONAN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem21', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD4', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem4']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[081] SEMIDANG AJI'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static52', '[081] SEMIDANG AJI', '[081] SEMIDANG AJIStatic']
#    |    |    |    |    |    |    |    | child_window(title="[081] SEMIDANG AJI", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem22', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD5', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem5']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[082] ULU OGAN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static53', '[082] ULU OGAN', '[082] ULU OGANStatic']
#    |    |    |    |    |    |    |    | child_window(title="[082] ULU OGAN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem23', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD6', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem6']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[083] MUARA JAYA'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static54', '[083] MUARA JAYA', '[083] MUARA JAYAStatic']
#    |    |    |    |    |    |    |    | child_window(title="[083] MUARA JAYA", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem24', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD7', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem7']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[090] PENINJAUAN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static55', '[090] PENINJAUAN', '[090] PENINJAUANStatic']
#    |    |    |    |    |    |    |    | child_window(title="[090] PENINJAUAN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem25', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD8', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem8']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[091] LUBUK BATANG'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static56', '[091] LUBUK BATANG', '[091] LUBUK BATANGStatic']
#    |    |    |    |    |    |    |    | child_window(title="[091] LUBUK BATANG", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem26', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD9', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem9']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[092] SINAR PENINJAUAN'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static57', '[092] SINAR PENINJAUANStatic', '[092] SINAR PENINJAUAN']
#    |    |    |    |    |    |    |    | child_window(title="[092] SINAR PENINJAUAN", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem27', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD10', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem10']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[093] KEDATON PENINJAUAN RAYA'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static58', '[093] KEDATON PENINJAUAN RAYAStatic', '[093] KEDATON PENINJAUAN RAYA']
#    |    |    |    |    |    |    |    | child_window(title="[093] KEDATON PENINJAUAN RAYA", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem28', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD11', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem11']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[130] BATU RAJA TIMUR'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static59', '[130] BATU RAJA TIMURStatic', '[130] BATU RAJA TIMUR']
#    |    |    |    |    |    |    |    | child_window(title="[130] BATU RAJA TIMUR", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem29', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD12', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem12']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[131] LUBUK RAJA'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static60', '[131] LUBUK RAJAStatic', '[131] LUBUK RAJA']
#    |    |    |    |    |    |    |    | child_window(title="[131] LUBUK RAJA", control_type="Text")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['ListItem30', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD13', 'System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DADListItem13']
#    |    |    |    |    |    |    | child_window(title="System.Data.Entity.DynamicProxies.m_kec_78DC5804F2F7D9F95B7542A522114DAF5DD05704E1CC164503D83B755D593DAD", control_type="ListItem")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Static - '[140] BATU RAJA BARAT'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    |    | ['Static61', '[140] BATU RAJA BARATStatic', '[140] BATU RAJA BARAT']
#    |    |    |    |    |    |    |    | child_window(title="[140] BATU RAJA BARAT", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - 'Desa : '    (L39, T325, R139, B341)
#    |    |    |    |    |    | ['Static62', 'Desa : ', 'Desa : Static']
#    |    |    |    |    |    | child_window(title="Desa : ", control_type="Text")
#    |    |    |    |    |    |
#    |    |    |    |    |    | ComboBox - ''    (L139, T322, R1580, B344)
#    |    |    |    |    |    | ['ComboBox[007] NEGERI RATU', 'ComboBox[009] SEGARA KEMBANG', 'ComboBox[014] TIHANG', 'ComboBox[018] BUNGA TANJUNG', 'ComboBox[008] LUBUK DALAM', 'ComboBox[016] NEGERI AGUNG', 'ComboBox[017] WAY HELING', 'ComboBox[005] TANJUNG LENGKAYAP', 'ComboBox[013] SUNDAN', 'ComboBox[011] GEDUNG PAKUAN', 'ComboBox[021] SIMPANG EMPAT', 'ComboBox[010] SUKARAJA', 'ComboBox[019] UMPAM', 'ComboBox[015] LUBUK HARA', 'ComboBox[004] PAGAR DEWA', 'ComboBox4', 'ComboBox[002] KARANG ENDAH', 'ComboBox[003] PAJAR BULAN', 'ComboBox[012] TUALANG', 'Desa : ComboBox', 'ComboBox[020] TANJUNG AGUNG', 'ComboBox[006] BUMI KAWA', 'ComboBox[022] FAJAR JAYA']
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | ListItem - 'System.Data.Entity.DynamicProxies.m_desa_E35B2E5BF7E4B48DF08E20B3FD44F72A3E6F06E273074DC3DE93617838CB7A78'    (L0, T0, R0, B0)
# ...
#    |    |    |    |    |    |    | ['Custom207', 'Item: , Column Display Index: 4Custom23', 'Item: , Column Display Index: 423']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 4", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 5'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 523', 'Custom208', 'Item: , Column Display Index: 5Custom23']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 5", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 6'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 623', 'Custom209', 'Item: , Column Display Index: 6Custom23']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 6", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 7'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 7Custom23', 'Custom210', 'Item: , Column Display Index: 723']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 7", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - ''    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom211']
#    |    |    |    |    |    |
#    |    |    |    |    |    | DataItem - '{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 17, id_rt = 17, status_dok = C, nama_krt = 15HftaSlirA=, nama_krt_temp = SARMAN, is_preprinted = 0, r114 = 1601283003720001, versi_rule = 3, is_final = False, realname = EVA }'    (L40, T878, R1873, B897)
#    |    |    |    |    |    | ['{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 17, id_rt = 17, status_dok = C, nama_krt = 15HftaSlirA=, nama_krt_temp = SARMAN, is_preprinted = 0, r114 = 1601283003720001, versi_rule = 3, is_final = False, realname = EVA }', 'DataItem24', '{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 17, id_rt = 17, status_dok = C, nama_krt = 15HftaSlirA=, nama_krt_temp = SARMAN, is_preprinted = 0, r114 = 1601283003720001, versi_rule = 3, is_final = False, realname = EVA }DataItem']
#    |    |    |    |    |    | child_window(title="{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 17, id_rt = 17, status_dok = C, nama_krt = 15HftaSlirA=, nama_krt_temp = SARMAN, is_preprinted = 0, r114 = 1601283003720001, versi_rule = 3, is_final = False, realname = EVA }", control_type="DataItem")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | HeaderItem - ''    (L40, T878, R56, B897)
#    |    |    |    |    |    |    | ['HeaderItem32', 'SLS - Sub SLS : HeaderItem24']
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Thumb - ''    (L40, T878, R56, B886)
#    |    |    |    |    |    |    |    | ['SLS - Sub SLS : Thumb46', 'Thumb63']
#    |    |    |    |    |    |    |    | child_window(auto_id="PART_TopHeaderGripper", control_type="Thumb")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Thumb - ''    (L40, T889, R56, B897)
#    |    |    |    |    |    |    |    | ['SLS - Sub SLS : Thumb47', 'Thumb64']
#    |    |    |    |    |    |    |    | child_window(auto_id="PART_BottomHeaderGripper", control_type="Thumb")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 0'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 024', 'Custom212', 'Item: , Column Display Index: 0Custom24']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 0", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 1'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom213', 'Item: , Column Display Index: 1Custom24', 'Item: , Column Display Index: 124']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 1", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 2'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 224', 'Custom214', 'Item: , Column Display Index: 2Custom24']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 2", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 3'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom215', 'Item: , Column Display Index: 3Custom24', 'Item: , Column Display Index: 324']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 3", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 4'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom216', 'Item: , Column Display Index: 4Custom24', 'Item: , Column Display Index: 424']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 4", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 5'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 524', 'Custom217', 'Item: , Column Display Index: 5Custom24']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 5", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 6'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 624', 'Custom218', 'Item: , Column Display Index: 6Custom24']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 6", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 7'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 7Custom24', 'Custom219', 'Item: , Column Display Index: 724']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 7", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - ''    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom220']
#    |    |    |    |    |    |
#    |    |    |    |    |    | DataItem - '{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 16, id_rt = 16, status_dok = C, nama_krt = hMp1D7xzOWU=, nama_krt_temp = ERMAN, is_preprinted = 0, r114 = 1601282107100002, versi_rule = 3, is_final = False, realname = EVA }'    (L40, T897, R1873, B916)
#    |    |    |    |    |    | ['DataItem25', '{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 16, id_rt = 16, status_dok = C, nama_krt = hMp1D7xzOWU=, nama_krt_temp = ERMAN, is_preprinted = 0, r114 = 1601282107100002, versi_rule = 3, is_final = False, realname = EVA }', '{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 16, id_rt = 16, status_dok = C, nama_krt = hMp1D7xzOWU=, nama_krt_temp = ERMAN, is_preprinted = 0, r114 = 1601282107100002, versi_rule = 3, is_final = False, realname = EVA }DataItem']
#    |    |    |    |    |    | child_window(title="{ prop = 16, kab = 01, kec = 052, desa = 001, sls = 0001, subsls = 00, sls_nama = RT 01 DUSUN 1, alamat = 1GX5QgJwc8i9XEqP6kAPcVL71Z3+1b1F+gr9g7FFOkI=, alamat_temp = DESA BANDAR JAYA RT 01 DUSUN 01, r110 = 16, id_rt = 16, status_dok = C, nama_krt = hMp1D7xzOWU=, nama_krt_temp = ERMAN, is_preprinted = 0, r114 = 1601282107100002, versi_rule = 3, is_final = False, realname = EVA }", control_type="DataItem")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | HeaderItem - ''    (L40, T897, R56, B916)
#    |    |    |    |    |    |    | ['HeaderItem33', 'SLS - Sub SLS : HeaderItem25']
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Thumb - ''    (L40, T897, R56, B905)
#    |    |    |    |    |    |    |    | ['SLS - Sub SLS : Thumb48', 'Thumb65']
#    |    |    |    |    |    |    |    | child_window(auto_id="PART_TopHeaderGripper", control_type="Thumb")
#    |    |    |    |    |    |    |    |
#    |    |    |    |    |    |    |    | Thumb - ''    (L40, T908, R56, B916)
#    |    |    |    |    |    |    |    | ['SLS - Sub SLS : Thumb49', 'Thumb66']
#    |    |    |    |    |    |    |    | child_window(auto_id="PART_BottomHeaderGripper", control_type="Thumb")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 0'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 025', 'Custom221', 'Item: , Column Display Index: 0Custom25']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 0", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 1'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom222', 'Item: , Column Display Index: 1Custom25', 'Item: , Column Display Index: 125']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 1", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 2'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 225', 'Custom223', 'Item: , Column Display Index: 2Custom25']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 2", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 3'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom224', 'Item: , Column Display Index: 3Custom25', 'Item: , Column Display Index: 325']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 3", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 4'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom225', 'Item: , Column Display Index: 4Custom25', 'Item: , Column Display Index: 425']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 4", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 5'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 525', 'Custom226', 'Item: , Column Display Index: 5Custom25']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 5", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 6'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 625', 'Custom227', 'Item: , Column Display Index: 6Custom25']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 6", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - 'Item: , Column Display Index: 7'    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Item: , Column Display Index: 7Custom25', 'Custom228', 'Item: , Column Display Index: 725']
#    |    |    |    |    |    |    | child_window(title="Item: , Column Display Index: 7", control_type="Custom")
#    |    |    |    |    |    |    |
#    |    |    |    |    |    |    | Custom - ''    (L0, T0, R0, B0)
#    |    |    |    |    |    |    | ['Custom229']
#    |    |    |    |    |
#    |    |    |    |    | Button - 'Update Sampel Pengganti'    (L0, T0, R0, B0)
#    |    |    |    |    | ['Update Sampel PenggantiButton', 'Button25', 'Update Sampel Pengganti']
#    |    |    |    |    | child_window(title="Update Sampel Pengganti", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - '[F12] Entry'    (L42, T914, R162, B939)
#    |    |    |    |    | ['Button26', '[F12] EntryButton', '[F12] Entry', '[F12] Entry0', '[F12] Entry1']
#    |    |    |    |    | child_window(title="[F12] Entry", control_type="Button")
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - '[F12] Entry'    (L74, T918, R130, B934)
#    |    |    |    |    |    | ['Static107', '[F12] EntryStatic', '[F12] Entry2']
#    |    |    |    |    |    | child_window(title="[F12] Entry", control_type="Text")
#    |    |    |    |    |
#    |    |    |    |    | Button - '[F4] Insert'    (L168, T914, R288, B939)
#    |    |    |    |    | ['Button27', '[F4] Insert', '[F4] InsertButton', '[F4] Insert0', '[F4] Insert1']
#    |    |    |    |    | child_window(title="[F4] Insert", control_type="Button")
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - '[F4] Insert'    (L202, T918, R254, B934)
#    |    |    |    |    |    | ['Static108', '[F4] Insert2', '[F4] InsertStatic']
#    |    |    |    |    |    | child_window(title="[F4] Insert", control_type="Text")
#    |    |    |    |    |
#    |    |    |    |    | Button - 'Edit'    (L294, T914, R414, B939)
#    |    |    |    |    | ['Button28', 'Edit2', 'EditButton']
#    |    |    |    |    | child_window(title="Edit", control_type="Button")
#    |    |    |    |    |    |
#    |    |    |    |    |    | Static - 'Edit'    (L344, T918, R364, B934)
#    |    |    |    |    |    | ['Static109', 'Edit3', 'EditStatic']
#    |    |    |    |    |    | child_window(title="Edit", control_type="Text")
#    |    |    |    |    |
#    |    |    |    |    | Button - '[F6] Delete'    (L0, T0, R0, B0)
#    |    |    |    |    | ['Button29', '[F6] Delete', '[F6] DeleteButton']
#    |    |    |    |    | child_window(title="[F6] Delete", control_type="Button")
#    |    |    |    |    |
#    |    |    |    |    | Button - 'Pindah Wilayah'    (L0, T0, R0, B0)
#    |    |    |    |    | ['Button30', 'Pindah WilayahButton', 'Pindah Wilayah']
#    |    |    |    |    | child_window(title="Pindah Wilayah", control_type="Button")
#    |    |
#    |    | CheckBox - 'Save Pengentri'    (L0, T0, R0, B0)
#    |    | ['CheckBox', 'Save Pengentri', 'Save PengentriCheckBox']
#    |    | child_window(title="Save Pengentri", control_type="CheckBox")
#    |    |
#    |    | Button - 'Close'    (L1769, T960, R1889, B987)
#    |    | ['Close3', 'Button31', 'CloseButton2']
#    |    | child_window(title="Close", auto_id="btnClose", control_type="Button")
#    |    |    |
#    |    |    | Static - '_Close'    (L1815, T965, R1843, B981)
#    |    |    | ['Static110', '_Close', '_CloseStatic']
#    |    |    | child_window(title="_Close", control_type="Text")
